# %%
import re
def a(w):t,m='█░';p=print;l=len(w);c=[len(s) if s else 0 for s in re.match(r'(do+)*(mi+)*(no+)*', w).groups()];a,b,d=c;[p(t*l) for i in range(a)];[p(' ' + m * (l-2)) for i in range(b)];[p(t*l) for i in range(d)]
a('dooomiiinooo')
# Out:
# ████████████
# ████████████
# ████████████
# ████████████
#  ░░░░░░░░░░
#  ░░░░░░░░░░
#  ░░░░░░░░░░
#  ░░░░░░░░░░
# ████████████
# ████████████
# ████████████
# ████████████

# %%
def a(n,m):n=int(n);print(max(([(eval('*'.join(m[i:i+n])),m[i:i+n]) for i in range(len(m))]))[-1])
a("3","535984")
# Out:
# 598

# %%
def a(f):s,b=set(f),f.count;o=[c for c in s if b(c)%2];e=[(c,b(c)//2) for c in s if b(c)>1];print('Pairs I have: '+"".join([f'{c} pair{["","s"][c>1]} of {v}, ' for v,c in e])[:-2]+'\nOdd socks: '+' '.join(o))
a("6214363336")
# Out:
# Pairs I have: 2 pairs of 3, 1 pair of 6
# Odd socks: 1 4 2 6

# %%
def d(s):[print('zeontwthfofisiseeini'.find(s[:2])//2,end='') for s in s.split()]
d('zero one two three nine four five six six six')
# Out:
# 0123945666

# %%
import requests as r
print([ind, x[:20] for ind, x in eumerate(r.get('http://www.alko.fi/tuotteet/000706').text.split('="'))]
# Out:
# ['\n\n<!doctype html><!-- BEGIN TEMPLATE app_sf_responsive_b2b/default/modules/b2bUtils/Modules --><!-- END TEMPLATE app_sf_responsive_b2b/default/modules/b2bUtils/Modules --><html lang', 'fi"><head>\n<script>\nrequestManifest();\nfunction requestManifest() {\nvar xmlHttp = new XMLHttpRequest();\nxmlHttp.open("GET", "/INTERSHOP/rest/WFS/Alko-OnlineShop-Site/-/storejson/manifest.json", false); // false for synchronous request\nxmlHttp.send(null);\nxmlHttp.onreadystatechange = manifestRequestResponseReceived(xmlHttp);\n}\nfunction manifestRequestResponseReceived(xmlHttp) {\nvar manifestExists = xmlHttp.responseText;\nif ( manifestExists == \'true\' ) {\nvar link = document.createElement(\'link\');\nlink.rel = "manifest";\nlink.href = "/INTERSHOP/static/BOS/Alko-Site/OnlineShop/Alko-OnlineShop/en_US/mobile-app/manifest.json";\ndocument.head.appendChild(link);\n}\n}\n</script><!-- BEGIN TEMPLATE alko_storefront/default/inc/header/ALKO_MetaTags -->\n<meta http-equiv', 'x-ua-compatible" co
# ...

# %%
def a(m):n=[0];i=0;exec("*x,l=n;n+=[x[::-1].index(l)+1 if l in x else 0];i+=1;"*(m-1));print(" ".join(map(str,n)))

m=int(open('3').read())
a(30)
# Out:
# 0 0 1 0 2 0 2 2 1 6 0 5 0 2 6 5 4 0 5 3 0 3 2 9 0 4 9 3 6 14

# %%
a,b,i,w=lambda x:['no more',str(x)][x>0],lambda n,r:f'bottle{["","s"][n!=1]} z{[" x",""][r]}',99,''
exec("c='GToa kteo  otnhee  dsotwonr ea nadn dp absusy  isto maer omuonrde';p=[99,i-1][i>0];w+=(f'{a(i).capitalize()} {b(i,0)}, {a(i)} {b(i,1)}.K{c[i>0::2]}, {a(p)} {b(p,0)}.KK'.replace('z', 'of beer').replace('x', 'on the wall'));i-=1;"*100)
print(w.replace('K', '\n'))
# Out:
# 99 bottles of beer on the wall, 99 bottles of beer.
# Take one down and pass it around, 98 bottles of beer on the wall.
#
# 98 bottles of beer on the wall, 98 bottles of beer.
# Take one down and pass it around, 97 bottles of beer on the wall.
#
# 97 bottles of beer on the wall, 97 bottles of beer.
# Take one down and pass it around, 96 bottles of beer on the wall.
#
# 96 bottles of beer on the wall, 96 bottles of beer.
# Take one down and pass it around, 95 bottles of beer on the wall.
#
# 95 bottles of beer on the wall, 95 bottles of beer.
# Take one down and pass it around, 94 bottles of beer on the wall.
#
# 94 bottles of beer on the wall, 94 bottles of beer.
# Take one down and pass it around, 93 bottles of beer on the wall.
#
# 93 bottles of beer on the wall, 93 bottles of beer.
# Take one down and pass it around, 92 bottles of beer on the wall.
#
# 92 bottles of beer on the wall, 92 bottles of beer.
# Take one down and pass it around, 91 bottles of beer on the wall.
#
# ...
